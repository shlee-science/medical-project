# %%
import cv2
from rembg import remove
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../data/train/1.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
img = remove(img)
plt.imshow(img)
plt.show()
# Out:
# ...
# 100%|########################################| 176M/176M [00:00<00:00, 186GB/s]

# %%
# 배경 제거 작업 및 합성 코드 작성할 것

# %%
import albumentations as A
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../data/train/1.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
transform = A.Rotate(limit=5, p=1)
img = transform(image=img)["image"]
plt.imshow(img)
plt.show()
